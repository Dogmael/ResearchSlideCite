# %% [markdown]
# # Download video

# %%
# %pip install pytubefix

# %%
from pytubefix import YouTube
from pytubefix.cli import on_progress

# %%
video_urls = {
    'cours 3': 'https://www.youtube.com/watch?v=WEB4N4xbAhI',
    'cours 5': 'https://www.youtube.com/watch?v=-tdC1Y4Wo2Y',
    'cours 7': 'https://www.youtube.com/watch?v=t90r_MMmHdQ',
    'cours 9': 'https://www.youtube.com/watch?v=ufLx_7YafmM',
    'cours 11': 'https://www.youtube.com/watch?v=-yqPZQYYwiI'
}

# %%
for cours_name, url in video_urls.items():
    print(f'Starting download of {cours_name}')
    yt = YouTube(url, use_oauth=True, on_progress_callback=on_progress)
    stream = yt.streams.filter(res="720p").first()
    stream.download(output_path='./videos', filename=f'video_{cours_name.replace(" ", "_")}.mp4')
    print(f'\nVideo of {cours_name} downloaded')

# %% [markdown]
# # Crop relevant part of the video

# %%
# %pip install opencv-python

# %%
import numpy as np
import cv2
import os

# %%
def video_processing(cap, interval, x, y, w_frame, h_frame):
    img_counter = 0

    frame_counter = 0  # Compteur pour suivre le nombre de frames traitées
    while(cap.isOpened()):
        ret, frame = cap.read()

        if ret:
            # Vérifier si le compteur de frames est un multiple de l'intervalle
            if frame_counter % interval == 0:
                print(f'Frame {frame_counter} captured')
                # Recadrage du cadre
                crop_frame = frame[y:h_frame, x:w_frame] # row, column

                # Sauvegarde de l'image recadrée
                cv2.imwrite(f'./screenshots/{cours_name.replace(" ", "_")}/screenshot_{img_counter}.jpg', crop_frame)
                img_counter += 1
        else:
            break

        frame_counter += 1

# %%
for cours_name, url in video_urls.items():
    print(f'Starting screenshot of {cours_name}')
    
    # Get video filename
    filename = f'video_{cours_name.replace(" ", "_")}.mp4'
    filepath = f'./videos/{filename}'
    
    # Open video
    cap = cv2.VideoCapture(filepath)
    
    # Original video characteristics
    w_frame, h_frame = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)   
    interval = int(fps * 30) # Get a frame every 30 seconds

    # Cropping values
    x,y = 250, 700 # column/width, row/height
    
    # Create screenshots folder
    os.makedirs(f'./screenshots/{cours_name.replace(" ", "_")}', exist_ok=True)
    
    # Video processing
    video_processing(cap, interval, x, y, w_frame, h_frame)
    
    # Nettoyage
    cap.release()
    cv2.destroyAllWindows()
    
    print(f'Screenshot of {cours_name} done')
# Out:
# Starting screenshot of cours 3
# Frame 0 captured
# Frame 750 captured
# Frame 1500 captured
# Frame 2250 captured
# Frame 3000 captured
# Frame 3750 captured
# Frame 4500 captured
# Frame 5250 captured
# Frame 6000 captured
# Frame 6750 captured
# Frame 7500 captured
# Frame 8250 captured
# Frame 9000 captured
# Frame 9750 captured
# Frame 10500 captured
# Frame 11250 captured
# Frame 12000 captured
# Frame 12750 captured
# Frame 13500 captured
# Frame 14250 captured
# Frame 15000 captured
# Frame 15750 captured
# Frame 16500 captured
# Frame 17250 captured
# Frame 18000 captured
# Frame 18750 captured
# Frame 19500 captured
# Frame 20250 captured
# Frame 21000 captured
# Frame 21750 captured
# Frame 22500 captured
# Frame 23250 captured
# Frame 24000 captured
# Frame 24750 captured
# Frame 25500 captured
# Frame 26250 captured
# Frame 27000 captured
# Frame 27750 captured
# Frame 28500 captured
# Frame 29250 captured
# Frame 30000 captured
# Frame 30750 captured
# Frame 31500 captured
# Frame 32250 captured
# Frame 33000 captured
# Frame 33750 captured
# Frame 34500 captured
# Frame 35250 captured
# Frame 36000 captured
# Frame 36750 captured
# Frame 37500 captured
# Frame 38250 captured
# Frame 39000 captured
# Frame 39750 captured
# Frame 40500 captured
# Frame 41250 captured
# Frame 42000 captured
# Frame 42750 captured
# Frame 43500 captured
# Frame 44250 captured
# Frame 45000 captured
# Frame 45750 captured
# Frame 46500 captured
# Frame 47250 captured
# Frame 48000 captured
# Frame 48750 captured
# Frame 49500 captured
# Frame 50250 captured
# Frame 51000 captured
# Frame 51750 captured
# Frame 52500 captured
# Frame 53250 captured
# Frame 54000 captured
# Frame 54750 captured
# Frame 55500 captured
# Frame 56250 captured
# Frame 57000 captured
# Frame 57750 captured
# Frame 58500 captured
# Frame 59250 captured
# Frame 60000 captured
# Frame 60750 captured
# Frame 61500 captured
# Frame 62250 captured
# Frame 63000 captured
# Frame 63750 captured
# Frame 64500 captured
# Frame 65250 captured
# Frame 66000 captured
# Frame 66750 captured
# Frame 67500 captured
# Frame 68250 captured
# Frame 69000 captured
# Frame 69750 captured
# Frame 70500 captured
# Frame 71250 captured
# Frame 72000 captured
# Frame 72750 captured
# Frame 73500 captured
# Frame 74250 captured
# Frame 75000 captured
# Frame 75750 captured
# Frame 76500 captured
# Frame 77250 captured
# Frame 78000 captured
# Frame 78750 captured
# Frame 79500 captured
# Frame 80250 captured
# Frame 81000 captured
# Frame 81750 captured
# Frame 82500 captured
# Frame 83250 captured
# Frame 84000 captured
# Frame 84750 captured
# Frame 85500 captured
# Frame 86250 captured
# Frame 87000 captured
# Frame 87750 captured
# Frame 88500 captured
# Frame 89250 captured
# Frame 90000 captured
# Frame 90750 captured
# Frame 91500 captured
# Frame 92250 captured
# Frame 93000 captured
# Frame 93750 captured
# Frame 94500 captured
# Frame 95250 captured
# Frame 96000 captured
# Frame 96750 captured
# Frame 97500 captured
# Frame 98250 captured
# Frame 99000 captured
# Frame 99750 captured
# Frame 100500 captured
# Screenshot of cours 3 done
# Starting screenshot of cours 5
# Frame 0 captured
# Frame 750 captured
# Frame 1500 captured
# Frame 2250 captured
# Frame 3000 captured
# Frame 3750 captured
# Frame 4500 captured
# Frame 5250 captured
# Frame 6000 captured
# Frame 6750 captured
# Frame 7500 captured
# Frame 8250 captured
# Frame 9000 captured
# Frame 9750 captured
# Frame 10500 captured
# Frame 11250 captured
# Frame 12000 captured
# Frame 12750 captured
# Frame 13500 captured
# Frame 14250 captured
# Frame 15000 captured
# Frame 15750 captured
# Frame 16500 captured
# Frame 17250 captured
# Frame 18000 captured
# Frame 18750 captured
# Frame 19500 captured
# Frame 20250 captured
# Frame 21000 captured
# Frame 21750 captured
# Frame 22500 captured
# Frame 23250 captured
# Frame 24000 captured
# Frame 24750 captured
# Frame 25500 captured
# Frame 26250 captured
# Frame 27000 captured
# Frame 27750 captured
# Frame 28500 captured
# Frame 29250 captured
# Frame 30000 captured
# Frame 30750 captured
# Frame 31500 captured
# Frame 32250 captured
# Frame 33000 captured
# Frame 33750 captured
# Frame 34500 captured
# Frame 35250 captured
# Frame 36000 captured
# Frame 36750 captured
# Frame 37500 captured
# Frame 38250 captured
# Frame 39000 captured
# Frame 39750 captured
# Frame 40500 captured
# Frame 41250 captured
# Frame 42000 captured
# Frame 42750 captured
# Frame 43500 captured
# Frame 44250 captured
# Frame 45000 captured
# Frame 45750 captured
# Frame 46500 captured
# Frame 47250 captured
# Frame 48000 captured
# Frame 48750 captured
# Frame 49500 captured
# Frame 50250 captured
# Frame 51000 captured
# Frame 51750 captured
# Frame 52500 captured
# Frame 53250 captured
# Frame 54000 captured
# Frame 54750 captured
# Frame 55500 captured
# Frame 56250 captured
# Frame 57000 captured
# Frame 57750 captured
# Frame 58500 captured
# Frame 59250 captured
# Frame 60000 captured
# Frame 60750 captured
# Frame 61500 captured
# Frame 62250 captured
# Frame 63000 captured
# Frame 63750 captured
# Frame 64500 captured
# Frame 65250 captured
# Frame 66000 captured
# Frame 66750 captured
# Frame 67500 captured
# Frame 68250 captured
# Frame 69000 captured
# Frame 69750 captured
# Frame 70500 captured
# Frame 71250 captured
# Frame 72000 captured
# Frame 72750 captured
# Frame 73500 captured
# Frame 74250 captured
# Frame 75000 captured
# Frame 75750 captured
# Frame 76500 captured
# Frame 77250 captured
# Frame 78000 captured
# Frame 78750 captured
# Frame 79500 captured
# Frame 80250 captured
# Frame 81000 captured
# Frame 81750 captured
# Frame 82500 captured
# Frame 83250 captured
# Frame 84000 captured
# Frame 84750 captured
# Frame 85500 captured
# Frame 86250 captured
# Frame 87000 captured
# Frame 87750 captured
# Frame 88500 captured
# Frame 89250 captured
# Frame 90000 captured
# Frame 90750 captured
# Frame 91500 captured
# Screenshot of cours 5 done
# Starting screenshot of cours 7
# Frame 0 captured
# Frame 750 captured
# Frame 1500 captured
# Frame 2250 captured
# Frame 3000 captured
# Frame 3750 captured
# Frame 4500 captured
# Frame 5250 captured
# Frame 6000 captured
# Frame 6750 captured
# Frame 7500 captured
# Frame 8250 captured
# Frame 9000 captured
# Frame 9750 captured
# Frame 10500 captured
# Frame 11250 captured
# Frame 12000 captured
# Frame 12750 captured
# Frame 13500 captured
# Frame 14250 captured
# Frame 15000 captured
# Frame 15750 captured
# Frame 16500 captured
# Frame 17250 captured
# Frame 18000 captured
# Frame 18750 captured
# Frame 19500 captured
# Frame 20250 captured
# Frame 21000 captured
# Frame 21750 captured
# Frame 22500 captured
# Frame 23250 captured
# Frame 24000 captured
# Frame 24750 captured
# Frame 25500 captured
# Frame 26250 captured
# Frame 27000 captured
# Frame 27750 captured
# Frame 28500 captured
# Frame 29250 captured
# Frame 30000 captured
# Frame 30750 captured
# Frame 31500 captured
# Frame 32250 captured
# Frame 33000 captured
# Frame 33750 captured
# Frame 34500 captured
# Frame 35250 captured
# Frame 36000 captured
# Frame 36750 captured
# Frame 37500 captured
# Frame 38250 captured
# Frame 39000 captured
# Frame 39750 captured
# Frame 40500 captured
# Frame 41250 captured
# Frame 42000 captured
# Frame 42750 captured
# Frame 43500 captured
# Frame 44250 captured
# Frame 45000 captured
# Frame 45750 captured
# Frame 46500 captured
# Frame 47250 captured
# Frame 48000 captured
# Frame 48750 captured
# Frame 49500 captured
# Frame 50250 captured
# Frame 51000 captured
# Frame 51750 captured
# Frame 52500 captured
# Frame 53250 captured
# Frame 54000 captured
# Frame 54750 captured
# Frame 55500 captured
# Frame 56250 captured
# Frame 57000 captured
# Frame 57750 captured
# Frame 58500 captured
# Frame 59250 captured
# Frame 60000 captured
# Frame 60750 captured
# Frame 61500 captured
# Frame 62250 captured
# Frame 63000 captured
# Frame 63750 captured
# Frame 64500 captured
# Frame 65250 captured
# Frame 66000 captured
# Frame 66750 captured
# Frame 67500 captured
# Frame 68250 captured
# Frame 69000 captured
# Frame 69750 captured
# Frame 70500 captured
# Frame 71250 captured
# Frame 72000 captured
# Frame 72750 captured
# Frame 73500 captured
# Frame 74250 captured
# Frame 75000 captured
# Frame 75750 captured
# Frame 76500 captured
# Frame 77250 captured
# Frame 78000 captured
# Frame 78750 captured
# Frame 79500 captured
# Frame 80250 captured
# Frame 81000 captured
# Frame 81750 captured
# Frame 82500 captured
# Frame 83250 captured
# Frame 84000 captured
# Frame 84750 captured
# Frame 85500 captured
# Frame 86250 captured
# Screenshot of cours 7 done
# Starting screenshot of cours 9
# Frame 0 captured
# Frame 750 captured
# Frame 1500 captured
# Frame 2250 captured
# Frame 3000 captured
# Frame 3750 captured
# Frame 4500 captured
# Frame 5250 captured
# Frame 6000 captured
# Frame 6750 captured
# Frame 7500 captured
# Frame 8250 captured
# Frame 9000 captured
# Frame 9750 captured
# Frame 10500 captured
# Frame 11250 captured
# Frame 12000 captured
# Frame 12750 captured
# Frame 13500 captured
# Frame 14250 captured
# Frame 15000 captured
# Frame 15750 captured
# Frame 16500 captured
# Frame 17250 captured
# Frame 18000 captured
# Frame 18750 captured
# Frame 19500 captured
# Frame 20250 captured
# Frame 21000 captured
# Frame 21750 captured
# Frame 22500 captured
# Frame 23250 captured
# Frame 24000 captured
# Frame 24750 captured
# Frame 25500 captured
# Frame 26250 captured
# Frame 27000 captured
# Frame 27750 captured
# Frame 28500 captured
# Frame 29250 captured
# Frame 30000 captured
# Frame 30750 captured
# Frame 31500 captured
# Frame 32250 captured
# Frame 33000 captured
# Frame 33750 captured
# Frame 34500 captured
# Frame 35250 captured
# Frame 36000 captured
# Frame 36750 captured
# Frame 37500 captured
# Frame 38250 captured
# Frame 39000 captured
# Frame 39750 captured
# Frame 40500 captured
# Frame 41250 captured
# Frame 42000 captured
# Frame 42750 captured
# Frame 43500 captured
# Frame 44250 captured
# Frame 45000 captured
# Frame 45750 captured
# Frame 46500 captured
# Frame 47250 captured
# Frame 48000 captured
# Frame 48750 captured
# Frame 49500 captured
# Frame 50250 captured
# Frame 51000 captured
# Frame 51750 captured
# Frame 52500 captured
# Frame 53250 captured
# Frame 54000 captured
# Frame 54750 captured
# Frame 55500 captured
# Frame 56250 captured
# Frame 57000 captured
# Frame 57750 captured
# Frame 58500 captured
# Frame 59250 captured
# Frame 60000 captured
# Frame 60750 captured
# Frame 61500 captured
# Frame 62250 captured
# Frame 63000 captured
# Frame 63750 captured
# Frame 64500 captured
# Frame 65250 captured
# Frame 66000 captured
# Frame 66750 captured
# Frame 67500 captured
# Frame 68250 captured
# Frame 69000 captured
# Frame 69750 captured
# Frame 70500 captured
# Frame 71250 captured
# Frame 72000 captured
# Frame 72750 captured
# Frame 73500 captured
# Frame 74250 captured
# Frame 75000 captured
# Frame 75750 captured
# Frame 76500 captured
# Frame 77250 captured
# Frame 78000 captured
# Frame 78750 captured
# Frame 79500 captured
# Frame 80250 captured
# Frame 81000 captured
# Frame 81750 captured
# Frame 82500 captured
# Frame 83250 captured
# Frame 84000 captured
# Frame 84750 captured
# Frame 85500 captured
# Frame 86250 captured
# Frame 87000 captured
# Frame 87750 captured
# Frame 88500 captured
# Frame 89250 captured
# Frame 90000 captured
# Frame 90750 captured
# Frame 91500 captured
# Frame 92250 captured
# Frame 93000 captured
# Frame 93750 captured
# Frame 94500 captured
# Frame 95250 captured
# Frame 96000 captured
# Frame 96750 captured
# Frame 97500 captured
# Frame 98250 captured
# Frame 99000 captured
# Frame 99750 captured
# Frame 100500 captured
# Frame 101250 captured
# Screenshot of cours 9 done
# Starting screenshot of cours 11
# Frame 0 captured
# Frame 750 captured
# Frame 1500 captured
# Frame 2250 captured
# Frame 3000 captured
# Frame 3750 captured
# Frame 4500 captured
# Frame 5250 captured
# Frame 6000 captured
# Frame 6750 captured
# Frame 7500 captured
# Frame 8250 captured
# Frame 9000 captured
# Frame 9750 captured
# Frame 10500 captured
# Frame 11250 captured
# Frame 12000 captured
# Frame 12750 captured
# Frame 13500 captured
# Frame 14250 captured
# Frame 15000 captured
# Frame 15750 captured
# Frame 16500 captured
# Frame 17250 captured
# Frame 18000 captured
# Frame 18750 captured
# Frame 19500 captured
# Frame 20250 captured
# Frame 21000 captured
# Frame 21750 captured
# Frame 22500 captured
# Frame 23250 captured
# Frame 24000 captured
# Frame 24750 captured
# Frame 25500 captured
# Frame 26250 captured
# Frame 27000 captured
# Frame 27750 captured
# Frame 28500 captured
# Frame 29250 captured
# Frame 30000 captured
# Frame 30750 captured
# Frame 31500 captured
# Frame 32250 captured
# Frame 33000 captured
# Frame 33750 captured
# Frame 34500 captured
# Frame 35250 captured
# Frame 36000 captured
# Frame 36750 captured
# Frame 37500 captured
# Frame 38250 captured
# Frame 39000 captured
# Frame 39750 captured
# Frame 40500 captured
# Frame 41250 captured
# Frame 42000 captured
# Frame 42750 captured
# Frame 43500 captured
# Frame 44250 captured
# Frame 45000 captured
# Frame 45750 captured
# Frame 46500 captured
# Frame 47250 captured
# Frame 48000 captured
# Frame 48750 captured
# Frame 49500 captured
# Frame 50250 captured
# Frame 51000 captured
# Frame 51750 captured
# Frame 52500 captured
# Frame 53250 captured
# Frame 54000 captured
# Frame 54750 captured
# Frame 55500 captured
# Frame 56250 captured
# Frame 57000 captured
# Frame 57750 captured
# Frame 58500 captured
# Frame 59250 captured
# Frame 60000 captured
# Frame 60750 captured
# Frame 61500 captured
# Frame 62250 captured
# Frame 63000 captured
# Frame 63750 captured
# Frame 64500 captured
# Frame 65250 captured
# Frame 66000 captured
# Frame 66750 captured
# Frame 67500 captured
# Frame 68250 captured
# Frame 69000 captured
# Frame 69750 captured
# Frame 70500 captured
# Frame 71250 captured
# Frame 72000 captured
# Frame 72750 captured
# Frame 73500 captured
# Frame 74250 captured
# Frame 75000 captured
# Frame 75750 captured
# Frame 76500 captured
# Frame 77250 captured
# Frame 78000 captured
# Frame 78750 captured
# Frame 79500 captured
# Frame 80250 captured
# Frame 81000 captured
# Frame 81750 captured
# Frame 82500 captured
# Frame 83250 captured
# Frame 84000 captured
# Frame 84750 captured
# Frame 85500 captured
# Frame 86250 captured
# Frame 87000 captured
# Frame 87750 captured
# Frame 88500 captured
# Frame 89250 captured
# Frame 90000 captured
# Frame 90750 captured
# Frame 91500 captured
# Frame 92250 captured
# Frame 93000 captured
# Frame 93750 captured
# Frame 94500 captured
# Frame 95250 captured
# Screenshot of cours 11 done

# %% [markdown]
# # Remove images without text

# %%
# %pip install opencv-python pytesseract pandas

# %%
import cv2
import pytesseract
import os
import pandas as pd

# %%
def detect_text_in_image(image_path):
    # Read the image
    img = cv2.imread(image_path)
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Use Tesseract to detect text
    text = pytesseract.image_to_string(gray)
    return text.strip()

# %%
screenshots_dirs = ['./screenshots/cours_3','./screenshots/cours_5', './screenshots/cours_7', './screenshots/cours_9', './screenshots/cours_11']

# %%
for screenshots_dir in screenshots_dirs:
    print(f'Removing unrelevant images from {screenshots_dir}')
    os.makedirs(f'{screenshots_dir}/unrelevant', exist_ok=True)
    
    image_files = [f for f in os.listdir(screenshots_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    for image_file in image_files:
        try :
            detected_text = detect_text_in_image(f'{screenshots_dir}/{image_file}')
            if not detected_text:
                print(f'No text detected in {image_file}')
                # Move image to unrelevant folder
                os.rename(f'{screenshots_dir}/{image_file}', f'{screenshots_dir}/unrelevant/{image_file}')
        except Exception as e:
            print(f'Error processing {image_file}: {str(e)}')
    print(f'Unrelevant images removed from {screenshots_dir}')

# %% [markdown]
# # Read text from images

# %%
screenshots_dirs = ['./screenshots/cours_3']

# %%
def read_text_from_image(image_path):
    # Read the image
    img = cv2.imread(image_path)
    # Use Tesseract to detect text
    text = pytesseract.image_to_string(img)
    return text.strip()

# %%
df = pd.DataFrame()

for screenshots_dir in screenshots_dirs:
    print(f'Reading text from {screenshots_dir}')
    
    image_files = [f for f in os.listdir(screenshots_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    for image_file in image_files:
        try :
            detected_text = detect_text_in_image(f'{screenshots_dir}/{image_file}')
            print(f'Text detected in {image_file}: {detected_text}')
            df = pd.concat([df, pd.DataFrame({'filename': [image_file], 'text': [detected_text]})], ignore_index=True)
        except Exception as e:
            print(f'Error processing {image_file}: {str(e)}')
            df = pd.concat([df, pd.DataFrame({'filename': [image_file], 'text': [None]})], ignore_index=True)
            
    print(f'Text read from {screenshots_dir}')

    df.to_csv(f'./text_from_images_{screenshots_dir.split("/")[-1]}.csv', index=False)
