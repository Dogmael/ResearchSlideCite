# %%
import json
import pandas as pd

# %%
# Process OCR results
with open("ocr_results_clean.json", "r") as f:
    ocr_results = json.load(f)

print(ocr_results)

# Make a dataframe with the results
df = pd.DataFrame(ocr_results.items(), columns=["image", "text"])

video_urls = {
    'cours 3': 'https://www.youtube.com/watch?v=WEB4N4xbAhI',
    'cours 5': 'https://www.youtube.com/watch?v=-tdC1Y4Wo2Y',
    'cours 7': 'https://www.youtube.com/watch?v=t90r_MMmHdQ',
    'cours 9': 'https://www.youtube.com/watch?v=ufLx_7YafmM',
    'cours 11': 'https://www.youtube.com/watch?v=-yqPZQYYwiI'
}

# Add a column with the video url
df['video_url'] = df['image'].apply(lambda x: video_urls[" ".join(x.split("_")[0:2])])

# Add time of the video in url (the number at the end of the url) at the end of the url (youtube url)
df['video_time'] = df['image'].apply(lambda x: int(x.split("_")[-1].split(".")[0])*30)

# Add a column with the video url with the time
df['video_url_with_time'] = df['video_url'] + "&t=" + df['video_time'].astype(str)

# Add the name of the course to the dataframe
df['Course number'] = df['image'].apply(lambda x: (x.split("_")[1])).astype(int)

# Add sort column
df = df.sort_values(by=['Course number', 'video_time'], ascending=[True, True])

# Select the columns we want
df = df[['Course number', 'text', 'video_url_with_time']]

df = df.rename(columns={"text": "Citation", "video_url_with_time": "URL"})

df
# Out:
# {'cours_7_screenshot_77.jpg': 'L. Marec, L. Quetel, et al. Insitu optical fibre sensors for temperature and salinity monitoring, OCS 2005', 'cours_3_screenshot_66.jpg': 'K.J. Nelson et al. et al. Journal of the electrochemical society, 165(3) 2018', 'cours_3_screenshot_72.jpg': 'G. Yan et al. Journal of the electrochemical society, 165(2) 2018', 'cours_9_screenshot_27.jpg': 'Willets et al., Annu. Rev. Phys. Chem., 2007, 58, 267-97.', 'cours_11_screenshot_98.jpg': 'L Gold et al.. J. Power Sources. 343 536-544 (2017).', 'cours_9_screenshot_35.jpg': 'J. N. Anker et al., Nature Materials, 2008. 7.', 'cours_7_screenshot_70.jpg': 'T. Guao, H.W Tam et al Optics Expres Vol 17, 2009', 'cours_7_screenshot_72.jpg': 'A. Nedialkov et al. Batteries march 2019', 'cours_7_screenshot_99.jpg': 'S Maquis, G. Laffont, P. Ferdinand, et al. Optics Express, 2008', 'cours_9_screenshot_130.jpg': 'S.A. Pradanawati et al., Jouml of power source (2016)', 'cours_3_screenshot_88.jpg': 'M. Dollé et al. Journal of the electrochemical society A851-A857', 'cours_9_screenshot_1_22.jpg': 'Wadell et al., ACS Nano, 2014, 8, 12, 11925-11940.', 'cours_9_screenshot_2_22.jpg': 'Willets et al Annu Rev Phys Chem 2007 58 267.07', 'cours_9_screenshot_3_22.jpg': 'Stewart et al., Chem. Rev., 2008, 108, 494-521.', 'cours_3_screenshot_102.jpg': 'R.P. Day et al. Journal of the Electrochemical society, 162(14) 2015', 'cours_3_screenshot_7.jpg': 'D. Guyomard and J.M. Tarascon, J. Electrochem. Soc. Vol 175 (1992)', 'cours_5_screenshot_76.jpg': 'CJ Bae et al. Energy technology, 4, 2016', 'cours_7_screenshot_29.jpg': 'Tai. et al. Opt. Lett. 1987', 'cours_7_screenshot_15.jpg': 'J. Huang, L. Albero Blanquer et al., Nature Energy, 2020, 5, 674-683', 'cours_5_screenshot_74.jpg': 'J. Schwartz, Sommer et al. Mater. Res. Soc. Symp. Proc. Vol. 1740 © 2015', 'cours_3_screenshot_12.jpg': 'A. Blyr, C. Sigala et al. Jr. Electrochemical Soc. Vol. 145, 1998', 'cours_9_screenshot_53.jpg': 'M. L. Brongersma, Faraday Discussions, 2015, 178, 9-36', 'cours_9_screenshot_47.jpg': 'Willets et al., Annu. Rev. Phys. Chem., 2007, 58, 267-97.', 'cours_9_screenshot_91.jpg': 'V. Gusak et al. NANO letters, 12 (2012)', 'cours_5_screenshot_61.jpg': 'G. Yang et al. Measurement 46 (2013)', 'cours_3_screenshot_128.jpg': 'Joule 3 1-17 March 20 2019', 'cours_5_screenshot_65.jpg': 'M. Nascimento et al. Applied Thermal Engineering 149 (2019)', 'cours_5_screenshot_71.jpg': 'LW. Sommer et al; JECS 162 (14) 2015.', 'cours_5_screenshot_1_59.jpg': 'J. Bonefacino Light: Science & Applications 7 (3). (2018)', 'cours_5_screenshot_2_59.jpg': 'D. Vilarinho Sensors 2017, 17. 2924; doi:10.3390/s17122924', 'cours_9_screenshot_81.jpg': 'C. Langhammer et al. Nano. Lett., 10, 2010', 'cours_9_screenshot_1_57.jpg': 'E. Larsson et al., Nanophotonics, 2012, 1, 249-266.', 'cours_9_screenshot_2_57.jpg': 'J. Dai et al.. Sensors. 2017. 17. 577. Wadell et al., ACS Nano, 2014, 8, 12, 11925-11940.', 'cours_5_screenshot_58.jpg': 'J. Bonefacino Light: Science & Applications 7 (3). (2018)', 'cours_7_screenshot_11.jpg': 'J. Huang, L. Albero Blanquer et al, Nature energy August 2020', 'cours_11_screenshot_105.jpg': 'P Ladpli, F Kopsaftopoulos, F-K Chang, J. Power Sources. 384, 342-354 (2018).', 'cours_9_screenshot_55.jpg': 'Rifat et al., Sensors and Actuators B, 2017, 243, 311-325.', 'cours_9_screenshot_83.jpg': 'L. Tian, Nanotechnology 23(2012)', 'cours_9_screenshot_68.jpg': 'I. Zoric, E.M Larsson, Advanced Materials, 22, 2010', 'cours_5_screenshot_1_67.jpg': 'LW. Sommer et al: JECS 162 (14) 2015.', 'cours_5_screenshot_2_67.jpg': 'L.W. Sommer et al. Mater. Res. Soc. Symp. Proc. Vol. 1681 @ 2014', 'cours_7_screenshot_35.jpg': 'P. Nieva et al. ACS applied materials and interfaces, 2017, 9, 41284, 9,', 'cours_9_screenshot_59.jpg': 'E.M. Larson et al. Nano Lett. Vol.7, N°5 (2007)', 'cours_11_screenshot_36.jpg': 'T. Ohzuku et al. J. Electrochem. Soc. (1997)', 'cours_5_screenshot_94.jpg': 'J. Flemming et al. HardwareX 3 (2018)', 'cours_7_screenshot_34.jpg ...
#     Course number                                           Citation  \
# 15              3  D. Guyomard and J.M. Tarascon, J. Electrochem....
# 20              3  A. Blyr, C. Sigala et al. Jr. Electrochemical ...
# 57              3        P. Poizot et al. Nature, 407, 496-499, 2000
# 48              3  X. Ma... et al. Journal of the electrochemical...
# 47              3  K.J. Nelson et al. Journal of the electrochemi...
# ..            ...                                                ...
# 68             11               Z. Deng, et al. Joule 4, 1-13 (2020)
# 99             11  A.G. Hsieh et al. Energy Environ. Sci; (2015) ...
# 73             11  AG Hsieh et al., Energy Environ. Sci. 8, 1569-...
# 4              11  L Gold et al.. J. Power Sources. 343 536-544 (...
# 35             11  P Ladpli, F Kopsaftopoulos, F-K Chang, J. Powe...
#
#                                                   URL
# 15  https://www.youtube.com/watch?v=WEB4N4xbAhI&t=210
# 20  https://www.youtube.com/watch?v=WEB4N4xbAhI&t=360
# 57  https://www.youtube.com/watch?v=WEB4N4xbAhI&t=690
# 48  https://www.youtube.com/watch?v=WEB4N4xbAhI&t=810
# 47  https://www.youtube.com/watch?v=WEB4N4xbAhI&t=990
# ..                                                ...
# 68  https://www.youtube.com/watch?v=-yqPZQYYwiI&t=...
# 99  https://www.youtube.com/watch?v=-yqPZQYYwiI&t=...
# 73  https://www.youtube.com/watch?v=-yqPZQYYwiI&t=...
# 4   https://www.youtube.com/watch?v=-yqPZQYYwiI&t=...
# 35  https://www.youtube.com/watch?v=-yqPZQYYwiI&t=...
#
# [101 rows x 3 columns]

# %%
# Save the dataframe to a excel file
# %pip install openpyxl

df.to_excel("ocr_results.xlsx", index=False)
