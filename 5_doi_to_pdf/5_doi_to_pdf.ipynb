# %%
import requests
from bs4 import BeautifulSoup
import sys
import urllib.parse
import pandas as pd
import os

# %%
def get_pdf_url(doi, base_url):
    url = f"{base_url}/{doi}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    try:
        response = requests.get(url, headers=headers, timeout=30)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, "html.parser")

        # Find direct PDF link
        iframe = soup.find("iframe", id="pdf")
        if iframe:
            pdf_path = iframe.get("src")
            if pdf_path:
                return urllib.parse.urljoin(base_url, pdf_path)

        # Alternative for newer Sci-Hub versions
        button = soup.find("button", onclick=lambda x: x and "location.href" in x)
        if button:
            js_code = button["onclick"]
            pdf_path = js_code.split("=")[1].strip("';")
            return urllib.parse.urljoin(base_url, pdf_path)

        return None

    except Exception as e:
        print(f"Error accessing {base_url}: {str(e)}")
        return None


def download_pdf(pdf_url, filename, folder_path):
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(pdf_url, headers=headers, stream=True)
        response.raise_for_status()
        
        # Create the folder if it doesn't exist
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # Create the file in the folder
        with open(os.path.join(folder_path, filename), "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        return True
    except Exception as e:
        print(f"Error during download: {str(e)}")
        return False
    
def get_doi_from_doi_url(doi_url):
    # Get the DOI from the url "https://doi.org/10.1149/1.2069372" -> "10.1149/1.2069372"
    doi = doi_url.split("https://doi.org/")[1]
    return doi


def get_pdf_from_doi_url(doi_url, folder_path, ID):
    if len(sys.argv) != 2:
        print("Usage: python scihub_downloader.py <DOI>")
        sys.exit(1)

    scihub_domains = [
        "https://sci-hub.se",
        "https://sci-hub.st",
        "https://sci-hub.ru",
        "https://sci-hub.ee",
    ]

    pdf_url = None
    for domain in scihub_domains:
        print(f"Trying with domain: {domain}")
        doi = get_doi_from_doi_url(doi_url)
        pdf_url = get_pdf_url(doi, domain)
        if pdf_url:
            print(f"PDF found on {domain}")
            break

    if not pdf_url:
        print("Failed to locate PDF on all Sci-Hub domains")
        return
    filename = ID + ".pdf"
    
    print(f"Attempting download from: {pdf_url}")

    if download_pdf(pdf_url, filename, folder_path):
        print(f"PDF successfully saved as: {filename}")
    else:
        print("Download failed")

# %%
# Open references_with_doi_clean.csv
df = pd.read_csv(
    "../4_references_to_doi/references_with_doi_clean.csv",
    sep=";",
    engine="python",
    quotechar='"'
)

destination_folder = "Articles cours sensing JMT"

for index, row in df.iterrows():
    # Check if pdf is already download
    if os.path.exists(f"{destination_folder}/{row['ID']}.pdf"):
        print(f"PDF déjà téléchargé pour {row['Reference']}")
        continue
        
    # Download PDF
    print(f"Téléchargement du PDF pour {row['Reference']}")
    get_pdf_from_doi_url(row['DOI'], destination_folder, row['ID'])
# Out:
# PDF déjà téléchargé pour D. Guyomard and J.M. Tarascon, J. Electrochem. Soc. Vol 175 (1992)
# Téléchargement du PDF pour A. Blyr, C. Sigala et al. Jr. Electrochemical Soc. Vol. 145, 1998
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1149/1.1838235 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x113557d90>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1149/1.1838235 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ac690>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1149/1.1838235 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142aca50>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1149/1.1838235 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad090>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour P. Poizot et al. Nature, 407, 496-499, 2000
# PDF déjà téléchargé pour X. Ma... et al. Journal of the electrochemical society, 166(4) 2019
# PDF déjà téléchargé pour K.J. Nelson et al. Journal of the electrochemical society, 165, 2018
# PDF déjà téléchargé pour G.P. Aiken et al. Journal of he electrochemical society. 167 (2020).
# PDF déjà téléchargé pour J.E. Harlow et al. J. Electrochemical Society, 165 (2018)
# PDF déjà téléchargé pour H.M. Dahn et al. Journal of the electrochemical society, 159(9) 2012
# PDF déjà téléchargé pour K.J. Nelson et al. et al. Journal of the electrochemical society, 165(3) 2018
# PDF déjà téléchargé pour G. Yan et al. Journal of the electrochemical society, 165(2) 2018
# PDF déjà téléchargé pour M. Dollé et al. Journal of the electrochemical society A851-A857
# PDF déjà téléchargé pour J. Li, H. Liu, J. Xia et al, Journal of the Electrochemical Society, 164 (4) 2017
# PDF déjà téléchargé pour R.P. Day et al. Journal of the Electrochemical society, 162(14) 2015
# PDF déjà téléchargé pour D.P. Wilkinson, H. Blom, K. Brandt and D. Wainwright, Jr of power sources, 36 (1991)
# PDF déjà téléchargé pour Glazier et al J. Electrochem Soc. A3545-55 (2017)
# PDF déjà téléchargé pour Joule 3 1-17 March 20 2019
# PDF déjà téléchargé pour X. Wang et al. JECS. 154 (2007)
# PDF déjà téléchargé pour Knobloch et al. Journal of electronic packaging, Vol. 140 (2018)
# PDF déjà téléchargé pour J. Bonefacino. Thesis. Department of Electrical Engineering. The Hong Kong Polytechnic University. (2017)
# Téléchargement du PDF pour F Udd and WB Spillman Fiber optic sensors 2011
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1002/9781118014103.ch7 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad590>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1002/9781118014103.ch7 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ada90>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1002/9781118014103.ch7 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142adf90>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1002/9781118014103.ch7 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x113557890>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour J. Huang L Albero Blanquer et al. Nature energy August 2020
# PDF déjà téléchargé pour E Hud Proc of SPIE Vol 9098 (2014)
# PDF déjà téléchargé pour J. Bonefacino Light: Science & Applications 7 (3). (2018)
# PDF déjà téléchargé pour J. Bonefacino Light: Science & Applications 7 (3). (2018)
# PDF déjà téléchargé pour D. Vilarinho Sensors 2017, 17. 2924; doi:10.3390/s17122924
# PDF déjà téléchargé pour G. Yang et al. Measurement 46 (2013)
# Téléchargement du PDF pour M. Nascimento et al. Applied Thermal Engineering 149 (2019)
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1016/j.energy.2023.127479 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142add10>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1016/j.energy.2023.127479 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad810>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1016/j.energy.2023.127479 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad310>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1016/j.energy.2023.127479 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ace10>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour LW. Sommer et al: JECS 162 (14) 2015.
# PDF déjà téléchargé pour L.W. Sommer et al. Mater. Res. Soc. Symp. Proc. Vol. 1681 @ 2014
# Téléchargement du PDF pour LW. Sommer et al; JECS 162 (14) 2015.
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1186/s12887-021-03005-3 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ac550>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1186/s12887-021-03005-3 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ac410>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1186/s12887-021-03005-3 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ae490>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1186/s12887-021-03005-3 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ae990>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour J. Schwartz, Sommer et al. Mater. Res. Soc. Symp. Proc. Vol. 1740 © 2015
# PDF déjà téléchargé pour CJ Bae et al. Energy technology, 4, 2016
# PDF déjà téléchargé pour R. Gafsiand M.A. El-Sherif, Optical fiber technology 6, 299-323 (2000)
# PDF déjà téléchargé pour R.B Wagreich et al. Electronics letters June 1996 Vol. 32, N° 13
# PDF déjà téléchargé pour R. Gafsiand M.A. El-Sherif, Optical fiber technology 6, 299-323 (2000)
# PDF déjà téléchargé pour M. Nascimento et al. Batteries 2018, 4, 67
# Téléchargement du PDF pour Pinto et al. Journal of Power Sources 1-9, 2018
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1186/s13705-024-00475-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142aee90>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1186/s13705-024-00475-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142af390>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1186/s13705-024-00475-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142af890>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1186/s13705-024-00475-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142afd90>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour J. Flemming et al. HardwareX 3 (2018)
# PDF déjà téléchargé pour J. Huang, L. Albero Blanquer et al, Nature energy August 2020
# PDF déjà téléchargé pour J. Huang, L. Albero Blanquer et al, Nature energy August 2020
# PDF déjà téléchargé pour J. Huang, L. Albero Blanquer et al., Nature Energy, 2020, 5, 674-683
# PDF déjà téléchargé pour F. Chiavaioli et al. Nanophotoncs 2017.
# PDF déjà téléchargé pour M. Morisawa et al. Jornal of sensors 2012
# PDF déjà téléchargé pour Tai, et al. Opt. Lett. 1987
# PDF déjà téléchargé pour Tai. et al. Opt. Lett. 1987
# PDF déjà téléchargé pour Nieva, et al. ACS AMI. 2016
# PDF déjà téléchargé pour P. Nieva et al. ACS applied materials and interfaces, 2017, 9, 41284, 9,
# PDF déjà téléchargé pour J. Albert et al., Laser & Photonics, 2013, 7.83-108.
# PDF déjà téléchargé pour C. Caucheteur et al. Nature Communications 2016.
# PDF déjà téléchargé pour T. Guo et al., Optics and Laser Technology, 2016, 78, 19-33.
# PDF déjà téléchargé pour T. Guao, H.W Tam et al Optics Expres Vol 17, 2009
# PDF déjà téléchargé pour A. Nedialkov et al. Batteries march 2019
# PDF déjà téléchargé pour L. Marec, L. Quetel, et al. Insitu optical fibre sensors for temperature and salinity monitoring, OCS 2005
# PDF déjà téléchargé pour J.H. Chong et al. Optics Communications 229 (2004)
# PDF déjà téléchargé pour Marrec, L., Bourgerette, T., Datin, E., Ferchaud, N., Pucel, B., Quétel, L., Renault, C., & Tregoat, D. (2005). In-situ optical fibre sensors for temperature and salinity monitoring. In Oceans 2005 - Europe (Vol. 2, pp. 1276-1278). IEEE
# Téléchargement du PDF pour J. Janting, Journal of lightwave technology
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1364/ofs.2018.tue63 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142702d0>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1364/ofs.2018.tue63 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142707d0>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1364/ofs.2018.tue63 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114270cd0>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1364/ofs.2018.tue63 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114287610>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# Téléchargement du PDF pour Small and Robust All-Polymer Fiber Bragg Grating Based pH Sensor, DOI 10.1109/JLT. 2019.2902638
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1364/ofs.2018.the52 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x113557c50>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1364/ofs.2018.the52 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142afb10>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1364/ofs.2018.the52 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142af610>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1364/ofs.2018.the52 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142af110>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour A. Trouillet et al. Meas. Science Technology 17 (2006)
# PDF déjà téléchargé pour J. Dai et al, Sensors and Actuators B. 190 (2014)
# Téléchargement du PDF pour A. M. Cubillas et al. Chem Soc. Rev 2013
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1364/lacsea.2014.lm4d.5 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142aec10>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1364/lacsea.2014.lm4d.5 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ae710>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1364/lacsea.2014.lm4d.5 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ae210>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1364/lacsea.2014.lm4d.5 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ac690>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# Téléchargement du PDF pour S Maquis, G. Laffont, P. Ferdinand, et al. Optics Express, 2008
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.4324/9781315608730 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142aca50>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.4324/9781315608730 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad090>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.4324/9781315608730 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad590>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.4324/9781315608730 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ada90>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour E. Miele et al., ICTON 2020, 978-1-8423 2020 IEEE
# PDF déjà téléchargé pour Stephen et al. Proc. SPIE 6530, 2007
# PDF déjà téléchargé pour J. Huang et al. (2021)
# PDF déjà téléchargé pour M. McSherry et al. Sensor review Vol. 25 (2005)
# PDF déjà téléchargé pour M. Faraday. The Bakerian Lecture: Experimental Relations of Gold (and Other Metals), Light Philos. Trans. R. Soc. London. 1857. 147. 145-181
# PDF déjà téléchargé pour Wadell et al., ACS Nano, 2014, 8, 12, 11925-11940.
# PDF déjà téléchargé pour Willets et al Annu Rev Phys Chem 2007 58 267.07
# PDF déjà téléchargé pour Stewart et al., Chem. Rev., 2008, 108, 494-521.
# PDF déjà téléchargé pour Willets et al., Annu. Rev. Phys. Chem., 2007, 58, 267-97.
# PDF déjà téléchargé pour J. N. Anker et al., Nature Materials, 2008. 7.
# Téléchargement du PDF pour P.R. West et al. Laser and photonic review, 2020
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1117/1.jbo.25.4.040902 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x113557c50>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1117/1.jbo.25.4.040902 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x114287610>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1117/1.jbo.25.4.040902 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ada90>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1117/1.jbo.25.4.040902 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad590>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour Willets et al., Annu. Rev. Phys. Chem., 2007, 58, 267-97.
# PDF déjà téléchargé pour M. L. Brongersma, Faraday Discussions, 2015, 178, 9-36
# PDF déjà téléchargé pour Rifat et al., Sensors and Actuators B, 2017, 243, 311-325.
# PDF déjà téléchargé pour E. Larsson et al., Nanophotonics, 2012, 1, 249-266.
# PDF déjà téléchargé pour J. Dai et al.. Sensors. 2017. 17. 577. Wadell et al., ACS Nano, 2014, 8, 12, 11925-11940.
# PDF déjà téléchargé pour E.M. Larson et al. Nano Lett. Vol.7, N°5 (2007)
# PDF déjà téléchargé pour I. Zoric, E.M Larsson, Advanced Materials, 22, 2010
# PDF déjà téléchargé pour E.M. Laarson et el. Science. Vo. 326 (2009)
# PDF déjà téléchargé pour C. Langhammer et al. Nano Lett., 10, 2010
# PDF déjà téléchargé pour C. Langhammer et al. Nano. Lett., 10, 2010
# PDF déjà téléchargé pour L. Tian, Nanotechnology 23(2012)
# PDF déjà téléchargé pour V. Gusak et al. NANO letters, 12 (2012)
# PDF déjà téléchargé pour Y. Jin et al. PNAS Vol. 115, 544, 2008
# Téléchargement du PDF pour L. Albero Blanquer, MESC Master thesis, 2018.
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.25148/mmeurs.010558 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ad090>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.25148/mmeurs.010558 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142aca50>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.25148/mmeurs.010558 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ac690>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.25148/mmeurs.010558 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ae210>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour T. Guo et al.. Sensors 2017 17. 2732.
# PDF déjà téléchargé pour T. Guo et al., Jouranl of Lightwave Tech., 2017, 35, 16
# Téléchargement du PDF pour J.Lao et al., Light: Science & Applications, 2018, 7, 34.
# Trying with domain: https://sci-hub.se
# Error accessing https://sci-hub.se: HTTPSConnectionPool(host='sci-hub.se', port=443): Max retries exceeded with url: /10.1038/s41377-018-0040-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142ae710>: Failed to resolve 'sci-hub.se' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.st
# Error accessing https://sci-hub.st: HTTPSConnectionPool(host='sci-hub.st', port=443): Max retries exceeded with url: /10.1038/s41377-018-0040-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142aec10>: Failed to resolve 'sci-hub.st' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ru
# Error accessing https://sci-hub.ru: HTTPSConnectionPool(host='sci-hub.ru', port=443): Max retries exceeded with url: /10.1038/s41377-018-0040-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142af110>: Failed to resolve 'sci-hub.ru' ([Errno 8] nodename nor servname provided, or not known)"))
# Trying with domain: https://sci-hub.ee
# Error accessing https://sci-hub.ee: HTTPSConnectionPool(host='sci-hub.ee', port=443): Max retries exceeded with url: /10.1038/s41377-018-0040-y (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1142af610>: Failed to resolve 'sci-hub.ee' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to locate PDF on all Sci-Hub domains
# PDF déjà téléchargé pour S.A. Pradanawati et al., Jouml of power source (2016)
# PDF déjà téléchargé pour Lemaire et al.. Anal. Chem. 2020.
# PDF déjà téléchargé pour T. Ohzuku et al. J. Electrochem. Soc. (1997)
# PDF déjà téléchargé pour N. Kircheva et al. J. Electrochem. Soc. (2011)
# PDF déjà téléchargé pour K. Rhodes et al. Journal of the electrochemical society. 157 (12) 2010
# PDF déjà téléchargé pour K. Rhodes et al. Review of Scientific Instrumentation (2011)
# PDF déjà téléchargé pour Chan-yang Choe et al. Materials transactions (2)(2015)
# PDF déjà téléchargé pour Z. Deng, et al. Joule 4, 1-13 (2020)
# PDF déjà téléchargé pour A.G. Hsieh et al. Energy Environ. Sci; (2015) DOI:10.1039/c5ee0011k
# PDF déjà téléchargé pour AG Hsieh et al., Energy Environ. Sci. 8, 1569-1577 (2015).
# PDF déjà téléchargé pour L Gold et al.. J. Power Sources. 343 536-544 (2017).
# PDF déjà téléchargé pour P Ladpli, F Kopsaftopoulos, F-K Chang, J. Power Sources. 384, 342-354 (2018).
