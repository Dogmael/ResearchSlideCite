# %% [markdown]
# # Preprocessing images

# %%
import cv2
import numpy as np
from PIL import Image, ImageFilter, ImageEnhance, ImageOps
import matplotlib.pyplot as plt
import os

# %%
def preprocess_image(image_path):
    # Open the image with Pillow
    img = Image.open(image_path)
    
    # Image dimensions
    width, height = img.size
    
    # Enlargement by a factor, e.g., 4
    factor = 4
    new_width = width * factor
    new_height = height * factor

    # Resize with quality interpolation
    resized_img = img.resize((new_width, new_height), Image.LANCZOS)

    # Apply a sharpening filter
    resized_img = resized_img.filter(ImageFilter.SHARPEN)

    # Increase contrast
    enhancer = ImageEnhance.Contrast(resized_img)
    resized_img = enhancer.enhance(5.0)  # 2.0 = double the contrast
    
    # Convert to grayscale
    gray_img = resized_img.convert("L")
    
    # Invert (black text on white background) if necessary
    gray_img = ImageOps.invert(gray_img)

    # Convert Pillow -> NumPy for OpenCV
    gray_img = np.array(gray_img)       
    
    # Apply the morphological "opening" operation
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
    opened_np = cv2.morphologyEx(gray_img, cv2.MORPH_OPEN, kernel)
    
    # Display the result
    # plt.figure(figsize=(30, 10))
    # plt.imshow(opened_np, cmap='gray')
    # plt.show()
    
    return opened_np

# %%
original_folders = ["../1_videos_to_relevant_screenshots/relevant_screenshots/cours_3",
                    "../1_videos_to_relevant_screenshots/relevant_screenshots/cours_5",
                    "../1_videos_to_relevant_screenshots/relevant_screenshots/cours_7",
                    "../1_videos_to_relevant_screenshots/relevant_screenshots/cours_9",
                    "../1_videos_to_relevant_screenshots/relevant_screenshots/cours_11"]

destination_folder = "./relevant_screenshots_processed"
os.makedirs(destination_folder, exist_ok=True)

for folder in original_folders:
    for image in os.listdir(folder):
        if image.endswith(".jpg"):
            processed_image = preprocess_image(os.path.join(folder, image))
            cv2.imwrite(os.path.join(destination_folder, f"{folder.split('/')[-1]}_{image}"), processed_image)

# %% [markdown]
# # OCR with Google Vision API

# %%
from google.cloud import vision
import os
import json
# Out:
# /Users/dogmael/Documents/Pro/Informatiques cours et projets/ResearchSlideCite/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def process_images_with_vision(folder_path):
    client = vision.ImageAnnotatorClient()
    results = {}

    for image_name in os.listdir(folder_path):
        if not image_name.endswith(".jpg"):
            continue

        image_path = os.path.join(folder_path, image_name)
        print(f"Processing {image_name}...")

        with open(image_path, "rb") as image_file:
            content = image_file.read()

        image = vision.Image(content=content)
        response = client.text_detection(image=image)

        if response.error.message:
            print(f"Error processing {image_name}: {response.error.message}")
            continue

        if response.text_annotations:
            # Le premier élément contient tout le texte
            print(f"OCR result for {image_name}: {response.text_annotations[0].description}")
            results[image_name] = response.text_annotations[0].description
        else:
            results[image_name] = ""

    return results

# %%
def ocr_with_google_vision():
    # Process all images
    results = process_images_with_vision("./relevant_screenshots_processed")

    # Save the results in a JSON file
    with open("ocr_results.json", "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

    print(f"Processed {len(results)} images. Results saved to ocr_results.json")

# %%
ocr_with_google_vision()
# Out:
# Processing cours_7_screenshot_77.jpg...
# OCR result for cours_7_screenshot_77.jpg: L. Marec, L. Quetel, et al. Insitu optical fibre sensors for temperature and salinity monitoring, OCS 2005
# Processing cours_3_screenshot_66.jpg...
# OCR result for cours_3_screenshot_66.jpg: K.J. Nelson et al. et al. Journal of the electrochemical society, 165(3) 2018
# Processing cours_3_screenshot_72.jpg...
# OCR result for cours_3_screenshot_72.jpg: G. Yan et al. Journal of the electrochemical society, 165(2) 2018
# Processing cours_9_screenshot_27.jpg...
# OCR result for cours_9_screenshot_27.jpg: Willets et al., Annu. Rev. Phys. Chem., 2007, 58, 267-97.
# Processing cours_11_screenshot_98.jpg...
# OCR result for cours_11_screenshot_98.jpg: L Gold et al.. J. Power Sources. 343 536-544 (2017).
# Processing cours_9_screenshot_35.jpg...
# OCR result for cours_9_screenshot_35.jpg: J. N. Anker et al., Nature Materials, 2008. 7.
# Processing cours_7_screenshot_70.jpg...
# OCR result for cours_7_screenshot_70.jpg: T. Guao, H.W Tam et al Optics Expres Vol 17, 2009
# Processing cours_7_screenshot_72.jpg...
# OCR result for cours_7_screenshot_72.jpg: A. Nedialkov et al. Batteries march 2019
# Processing cours_7_screenshot_99.jpg...
# OCR result for cours_7_screenshot_99.jpg: S Maquis, G. Laffont, P. Ferdinand, et al. Optics Express, 2008
# Processing cours_9_screenshot_130.jpg...
# OCR result for cours_9_screenshot_130.jpg: S.A. Pradanawati et al., Jouml of power source (2016)
# Processing cours_3_screenshot_88.jpg...
# OCR result for cours_3_screenshot_88.jpg: M. Dollé et al. Journal of the electrochemical society A851-A857
# Processing cours_9_screenshot_22.jpg...
# OCR result for cours_9_screenshot_22.jpg: Wadell et al., ACS Nano, 2014, 8, 12, 11925-11940.
# Willets et al Annu Rev Phys Chem 2007 58 267.07
# Stewart et al., Chem. Rev., 2008, 108, 494-521.
# Processing cours_3_screenshot_102.jpg...
# OCR result for cours_3_screenshot_102.jpg: R.P. Day et al. Journal of the Electrochemical society, 162(14) 2015
# Processing cours_3_screenshot_7.jpg...
# OCR result for cours_3_screenshot_7.jpg: D. Guyomard and J.M. Tarascon, J. Electrochem. Soc. Vol 175 (1992)
# Processing cours_5_screenshot_76.jpg...
# OCR result for cours_5_screenshot_76.jpg: CJ Bae et al. Energy technology, 4, 2016
# Processing cours_7_screenshot_29.jpg...
# OCR result for cours_7_screenshot_29.jpg: Tai. et al. Opt. Lett. 1987
# Processing cours_7_screenshot_15.jpg...
# OCR result for cours_7_screenshot_15.jpg: J. Huang, L. Albero Blanquer et al., Nature Energy, 2020, 5, 674-683
# Processing cours_5_screenshot_74.jpg...
# OCR result for cours_5_screenshot_74.jpg: J. Schwartz, Sommer et al. Mater. Res. Soc. Symp. Proc. Vol. 1740 © 2015
# Processing cours_3_screenshot_12.jpg...
# OCR result for cours_3_screenshot_12.jpg: A. Blyr, C. Sigala et al. Jr. Electrochemical Soc. Vol. 145, 1998
# Processing cours_3_screenshot_5.jpg...
# OCR result for cours_3_screenshot_5.jpg: Courtoisie de J. Dahn
# Processing cours_9_screenshot_53.jpg...
# OCR result for cours_9_screenshot_53.jpg: M. L. Brongersma, Faraday Discussions, 2015, 178, 9-36
# Processing cours_9_screenshot_47.jpg...
# OCR result for cours_9_screenshot_47.jpg: Willets et al., Annu. Rev. Phys. Chem., 2007, 58, 267-97.
# Processing cours_9_screenshot_91.jpg...
# OCR result for cours_9_screenshot_91.jpg: V. Gusak et al. NANO letters, 12 (2012)
# Processing cours_5_screenshot_61.jpg...
# OCR result for cours_5_screenshot_61.jpg: G. Yang et al. Measurement 46 (2013)
# Processing cours_3_screenshot_100.jpg...
# OCR result for cours_3_screenshot_100.jpg: Courtoisie de J. Dahn
# Processing cours_3_screenshot_128.jpg...
# OCR result for cours_3_screenshot_128.jpg: Joule 3 1-17 March 20 2019
# Processing cours_5_screenshot_65.jpg...
# OCR result for cours_5_screenshot_65.jpg: M. Nascimento et al. Applied Thermal Engineering 149 (2019)
# Processing cours_5_screenshot_71.jpg...
# OCR result for cours_5_screenshot_71.jpg: LW. Sommer et al; JECS 162 (14) 2015.
# Processing cours_5_screenshot_59.jpg...
# OCR result for cours_5_screenshot_59.jpg: Temps
# J. Bonefacino Light: Science & Applications 7 (3). (2018)
# D. Vilarinho Sensors 2017, 17. 2924; doi:10.3390/s17122924
# Processing cours_9_screenshot_81.jpg...
# OCR result for cours_9_screenshot_81.jpg: C. Langhammer et al. Nano. Lett., 10, 2010
# Processing cours_9_screenshot_57.jpg...
# OCR result for cours_9_screenshot_57.jpg: E. Larsson et al., Nanophotonics, 2012, 1, 249-266.
# J. Dai et al.. Sensors. 2017. 17. 577. Wadell et al., ACS Nano, 2014, 8, 12, 11925-11940.
# Processing cours_5_screenshot_58.jpg...
# OCR result for cours_5_screenshot_58.jpg: Temps
# J. Bonefacino Light: Science & Applications 7 (3). (2018)
# Processing cours_7_screenshot_11.jpg...
# OCR result for cours_7_screenshot_11.jpg: J. Huang, L. Albero Blanquer et al, Nature energy August 2020
# Processing cours_11_screenshot_105.jpg...
# OCR result for cours_11_screenshot_105.jpg: P Ladpli, F Kopsaftopoulos, F-K Chang, J. Power Sources. 384, 342-354 (2018).
# Processing cours_9_screenshot_55.jpg...
# OCR result for cours_9_screenshot_55.jpg: Rifat et al., Sensors and Actuators B, 2017, 243, 311-325.
# Processing cours_9_screenshot_83.jpg...
# OCR result for cours_9_screenshot_83.jpg: L. Tian, Nanotechnology 23(2012)
# Processing cours_9_screenshot_68.jpg...
# OCR result for cours_9_screenshot_68.jpg: I. Zoric, E.M Larsson, Advanced Materials, 22, 2010
# Processing cours_5_screenshot_67.jpg...
# OCR result for cours_5_screenshot_67.jpg: LW. Sommer et al: JECS 162 (14) 2015.
# L.W. Sommer et al. Mater. Res. Soc. Symp. Proc. Vol. 1681 @ 2014
# Processing cours_7_screenshot_35.jpg...
# OCR result for cours_7_screenshot_35.jpg: P. Nieva et al. ACS applied materials and interfaces, 2017, 9, 41284, 9,
# Processing cours_3_screenshot_18.jpg...
# OCR result for cours_3_screenshot_18.jpg: V. Pralong, thèse
# Processing cours_9_screenshot_59.jpg...
# OCR result for cours_9_screenshot_59.jpg: E.M. Larson et al. Nano Lett. Vol.7, N°5 (2007)
# Processing cours_11_screenshot_36.jpg...
# OCR result for cours_11_screenshot_36.jpg: T. Ohzuku et al. J. Electrochem. Soc. (1997)
# Processing cours_5_screenshot_94.jpg...
# OCR result for cours_5_screenshot_94.jpg: J. Flemming et al. HardwareX 3 (2018)
# Processing cours_7_screenshot_34.jpg...
# OCR result for cours_7_screenshot_34.jpg: Nieva, et al. ACS AMI. 2016
# Processing cours_5_screenshot_82.jpg...
# OCR result for cours_5_screenshot_82.jpg: R. Gafsiand M.A. El-Sherif, Optical fiber technology 6, 299-323 (2000)
# Processing cours_3_screenshot_33.jpg...
# OCR result for cours_3_screenshot_33.jpg: K.J. Nelson e al
# et al. Journal of the electrochemical society, 165, 2018
# Processing cours_3_screenshot_27.jpg...
# OCR result for cours_3_screenshot_27.jpg: X. Ma... et al. Journal of the electrochemical society, 166(4) 2019
# Processing cours_5_screenshot_54.jpg...
# OCR result for cours_5_screenshot_54.jpg: E Hud Proc of SPIE Vol 9098 (2014)
# Processing cours_3_screenshot_131.jpg...
# OCR result for cours_3_screenshot_131.jpg: X. Wang et al. JECS. 154 (2007)
# Knobloch et al. Journal of electronic packaging, Vol. 140 (2018)
# Processing cours_7_screenshot_27.jpg...
# OCR result for cours_7_screenshot_27.jpg: Tai, et al. Opt. Lett. 1987
# Processing cours_3_screenshot_36.jpg...
# OCR result for cours_3_screenshot_36.jpg: G.P. Aiken et al. Journal of he electrochemical society. 167 (2020).
# Processing cours_9_screenshot_77.jpg...
# OCR result for cours_9_screenshot_77.jpg: E.M. Laarson et el. Science. Vo. 326 (2009)
# C. Langhammer et al. Nano Lett., 10, 2010
# Processing cours_11_screenshot_24.jpg...
# OCR result for cours_11_screenshot_24.jpg: Lemaire et al.. Anal. Chem. 2020.
# Processing cours_3_screenshot_23.jpg...
# OCR result for cours_3_screenshot_23.jpg: P. Poizot et al. Nature, 407, 496-499, 2000
# Processing cours_5_screenshot_45.jpg...
# OCR result for cours_5_screenshot_45.jpg: J. Huang L Albero Blanquer et al. Nature energy August 2020
# Processing cours_3_screenshot_118.jpg...
# OCR result for cours_3_screenshot_118.jpg: D.P. Wilkinson, H. Blom, K. Brandt and D. Wainwright, Jr of power sources, 36 (1991)
# Processing cours_3_screenshot_124.jpg...
# OCR result for cours_3_screenshot_124.jpg: Glazier et al J. Electrochem Soc. A3545-55 (2017)
# Processing cours_5_screenshot_90.jpg...
# OCR result for cours_5_screenshot_90.jpg: Pinto et al. Journal of Power Sources 1-9, 2018
# Processing cours_5_screenshot_84.jpg...
# OCR result for cours_5_screenshot_84.jpg: R.B Wagreich et al. Electronics letters June 1996 Vol. 32, N° 13
# R. Gafsiand M.A. El-Sherif, Optical fiber technology 6, 299-323 (2000)
# Processing cours_7_screenshot_24.jpg...
# OCR result for cours_7_screenshot_24.jpg: F. Chiavaioli et al. Nanophotoncs 2017.
# M. Morisawa et al. Jornal of sensors 2012
# Processing cours_5_screenshot_85.jpg...
# OCR result for cours_5_screenshot_85.jpg: M. Nascimento et al. Batteries 2018, 4, 67
# Processing cours_7_screenshot_95.jpg...
# OCR result for cours_7_screenshot_95.jpg: A. M. Cubillas et al. Chem Soc. Rev 2013 DOI, 10.1039/c »cs60128e
# Processing cours_11_screenshot_68.jpg...
# OCR result for cours_11_screenshot_68.jpg: Z. Deng, et al. Joule 4, 1-13 (2020)
# Processing cours_3_screenshot_90.jpg...
# OCR result for cours_3_screenshot_90.jpg: J. Li, H. Liu, J. Xia et al, Journal of the Electrochemical Society, 164 (4) 2017
# Processing cours_7_screenshot_104.jpg...
# OCR result for cours_7_screenshot_104.jpg: Stephen et al. Proc. SPIE 6530, 2007
# Processing cours_9_screenshot_12.jpg...
# OCR result for cours_9_screenshot_12.jpg: M. Faraday. The Bakerian Lecture: Experimental Relations of Gold (and Other Metals), Light Philos. Trans. R. Soc. London. 1857. 147. 145-181
# Processing cours_11_screenshot_41.jpg...
# OCR result for cours_11_screenshot_41.jpg: N. Kircheva et al. J. Electrochem. Soc. (2011)
# Processing cours_11_screenshot_96.jpg...
# OCR result for cours_11_screenshot_96.jpg: AG Hsieh et al., Energy Environ. Sci. 8, 1569-1577 (2015).
# Processing cours_7_screenshot_82.jpg...
# OCR result for cours_7_screenshot_82.jpg: Marrec, L.; Bourgerette, T.; Datin, E.; Ferchaud, N.; Pucel, B.; Quetel, L.; Renault, C.; Tregoat, D. (2005) Oceans 2005-Europe Volume 2. 1276 - 1278 Vol. 2
# Processing cours_5_screenshot_22.jpg...
# OCR result for cours_5_screenshot_22.jpg: J. Bonefacino. "Thesis. Department of Electrical Engineering. The Hong Kong Polytechnic University. (2017)
# Processing cours_9_screenshot_103.jpg...
# OCR result for cours_9_screenshot_103.jpg: Y. Jin et al. PNAS Vol. 115, 544), 2008
# Processing cours_7_screenshot_107.jpg...
# OCR result for cours_7_screenshot_107.jpg: J. Huang et al. (2021)
# Processing cours_9_screenshot_38.jpg...
# OCR result for cours_9_screenshot_38.jpg: P.R. West et al. Laser and photonic review, 2020
# Processing cours_5_screenshot_118.jpg...
# OCR result for cours_5_screenshot_118.jpg: J. Huang, L. Albero Blanquer et al, Nature energy August 2020
# Processing cours_11_screenshot_56.jpg...
# OCR result for cours_11_screenshot_56.jpg: Chan-yang Choe et al. Materials transactions (2)(2015)
# Processing cours_5_screenshot_37.jpg...
# OCR result for cours_5_screenshot_37.jpg: F Udd and WB Spillman Fiber optic sensors 2011
# Processing cours_9_screenshot_116.jpg...
# OCR result for cours_9_screenshot_116.jpg: J.Lao et al., Light: Science & Applications, 2018, 7, 34.
# Processing cours_7_screenshot_78.jpg...
# OCR result for cours_7_screenshot_78.jpg: J.H. Chong et al. Optics Communications 229 (2004)
# Processing cours_7_screenshot_50.jpg...
# OCR result for cours_7_screenshot_50.jpg: T. Guo et al., Optics and Laser Technology, 2016, 78, 19-33.
# Processing cours_11_screenshot_46.jpg...
# OCR result for cours_11_screenshot_46.jpg: K. Rhodes et al. Journal of the electrochemical society. 157 (12) 2010
# Processing cours_11_screenshot_52.jpg...
# OCR result for cours_11_screenshot_52.jpg: K. Rhodes et al. Review of Scientific Instrumentation (2011)
# Processing cours_7_screenshot_86.jpg...
# OCR result for cours_7_screenshot_86.jpg: J. Janting, Journal of lighweight technology,
# DOI 10.1109/JLT. 2019.2902638
# Processing cours_9_screenshot_113.jpg...
# OCR result for cours_9_screenshot_113.jpg: T. Guo et al.. Sensors 2017 17. 2732.
# 1. Guo et al., Jouranl of Lightwave Tech., 2017, 35, 16
# Processing cours_7_screenshot_45.jpg...
# OCR result for cours_7_screenshot_45.jpg: J. Albert et al., Laser & Photonics, 2013, 7.83-108.
# C. Caucheteur et al. Nature Communications 2016.
# Processing cours_9_screenshot_105.jpg...
# OCR result for cours_9_screenshot_105.jpg: L. Albero Blanquer, MESC Master thesis, 2018.
# Processing cours_7_screenshot_90.jpg...
# OCR result for cours_7_screenshot_90.jpg: A
# Trouillet et al. Meas. Science Technology 17 (2006)
# J. Dai et al, Sensors and Actuators B. 190 (2014)
# Processing cours_3_screenshot_56.jpg...
# OCR result for cours_3_screenshot_56.jpg: H.M. Dahn et al. Journal of the electrochemical society, 159(9) 2012
# Processing cours_3_screenshot_81.jpg...
# OCR result for cours_3_screenshot_81.jpg: Courtourtésie de J. Dahn
# Processing cours_7_screenshot_114.jpg...
# OCR result for cours_7_screenshot_114.jpg: M. McSherry et al. Sensor review Vol. 25 (2005)
# Battery 2030: /European proiect INSTABAT
# Processing cours_7_screenshot_100.jpg...
# OCR result for cours_7_screenshot_100.jpg: E. Miele et al., ICTON 2020, 978-1-8423 2020 IEEE
# Processing cours_11_screenshot_93.jpg...
# OCR result for cours_11_screenshot_93.jpg: A.G. Hsieh et al. Energy Environ. Sci; (2015) DOI:10.1039/c5ee0011k
# Processing cours_3_screenshot_43.jpg...
# OCR result for cours_3_screenshot_43.jpg: J.E. Harlow et al. J. Electrochemical Society, 165 (2018)
# Processed 92 images. Results saved to ocr_results.json
